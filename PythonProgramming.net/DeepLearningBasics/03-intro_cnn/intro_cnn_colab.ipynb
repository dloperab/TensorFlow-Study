# %%
# install the necessary packages

# NumPy
# check version
import numpy as np
print(np.__version__)
# if version < 1.16.0, uncomment and update package
#!pip install numpy --upgrade
# Out:
# 1.16.0

# %%
# import the necessary packages
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from google.colab import drive

# %%
# mount gdrive in colab
drive.mount("/content/gdrive")
# list folders/files
#!ls "/content/gdrive/My Drive"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# load the features and labels with pickle
DATA_PATH = "/content/gdrive/My Drive/Colab Notebooks/TensorFlow/IntroDeepLearning/datasets/dogs-cats/" # replace to your path

pickle_in = open(DATA_PATH + "trainX.pickle", "rb")
trainX = pickle.load(pickle_in)

pickle_in = open(DATA_PATH + "trainY.pickle", "rb")
trainY = pickle.load(pickle_in)

# %%
# scale the raw pixel intensities to the range [0, 1]
trainX = trainX / 255.0

# %%
# define the architecture of the network
model = Sequential()
model.add(Conv2D(256, (3, 3), input_shape=trainX.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Activation("relu"))
model.add(Dense(1))
model.add(Activation("sigmoid"))

# %%
# train the model
model.compile(loss="binary_crossentropy",
             optimizer="adam",
             metrics=["accuracy"])
model.fit(trainX, trainY, batch_size=32, epochs=5, validation_split=0.3)
# Out:
# Train on 17462 samples, validate on 7484 samples
# Epoch 1/5
# 17462/17462 [==============================] - 19s 1ms/step - loss: 0.6472 - acc: 0.6212 - val_loss: 0.6052 - val_acc: 0.6828
# Epoch 2/5
# 17462/17462 [==============================] - 18s 1ms/step - loss: 0.5729 - acc: 0.7036 - val_loss: 0.5523 - val_acc: 0.7274
# Epoch 3/5
# 17462/17462 [==============================] - 18s 1ms/step - loss: 0.5277 - acc: 0.7376 - val_loss: 0.5195 - val_acc: 0.7467
# Epoch 4/5
# 17462/17462 [==============================] - 19s 1ms/step - loss: 0.4922 - acc: 0.7668 - val_loss: 0.5292 - val_acc: 0.7385
# Epoch 5/5
# 17462/17462 [==============================] - 18s 1ms/step - loss: 0.4560 - acc: 0.7839 - val_loss: 0.4898 - val_acc: 0.7652
